# %% [markdown]
# USING DATA ANALYSIS TO GENERATE INSIGHTS FOR MICROSOFT
#
# 1. Defining The Question
#
# Business Problem
# The company Microsoft is in a pivotal season of their business and they want exploratory data analysis done regarding content creation. The company has decided to create a movie studio for the same and want to develop a deeper understanding on creating movies through the guidance of the EDA. You are provided data about movie history ie the ratings, writers, directors, movie basics and what the movies are known for.
#
# Problem Statement
# You are charged with exploring what type of films are currently doing the best at the box office and translating those findings into actionable insights that Microsoft can use to decide what type of films to create.
#
# Defining the Metric for Success
# a) Data manipulation: To define what metrics of data you need to make your asssessment and dig deep
# b) Scope variance: to take an in-depth look at the movie project data available on how the cost affected the overall perfomance of the movies
# c) Financial metrics: this being the most important set of metrics for any project, and an even bigger deal in the entertainment industry.
#
# Understanding the Context
# This step is the process of understanding how data science affects the business of making original video content to gain as much information as possible for better business.
#
# Data Relevance
# The goal here is to create a level of consistency between the data presented and how this data will improve the decision making process at Microsoft regarding video content creation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Get CSV files list from a folder


# Read each CSV file into DataFrame
# This creates a list of dataframes

df_gross = pd.read_csv('Data\movie_gross.csv')
df_budgets = pd.read_csv('Data\movie_budgets.csv')
df_movies = pd.read_csv('Data\mdb_movies.csv')
df_budgets
# Out:
#       id release_date                                        movie
# 0      1    18-Dec-09                                       Avatar  \
# 1      2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2      3     7-Jun-19                                 Dark Phoenix
# 3      4     1-May-15                      Avengers: Age of Ultron
# 4      5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78    31-Dec-18                                       Red 11
# 5778  79     2-Apr-99                                    Following
# 5779  80    13-Jul-05                Return to the Land of Wonders
# 5780  81    29-Sep-15                         A Plague So Pleasant
# 5781  82     5-Aug-05                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross
# 0        $425,000,000   $760,507,625   $2,776,345,279
# ...

# %%
type(df_budgets)
# Out:
# pandas.core.frame.DataFrame

# %%
df_budgets.index
# Out:
# RangeIndex(start=0, stop=5782, step=1)

# %%
df_gross
# Out:
#                                             title      studio  domestic_gross
# 0                                     Toy Story 3          BV     415000000.0  \
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df_movies.head(20)
# Out:
#     Unnamed: 0                 genre_ids     id original_language
# 0            0           [12, 14, 10751]  12444                en  \
# 1            1       [14, 12, 16, 10751]  10191                en
# 2            2             [12, 28, 878]  10138                en
# 3            3           [16, 35, 10751]    862                en
# 4            4             [28, 878, 12]  27205                en
# 5            5           [12, 14, 10751]  32657                en
# 6            6         [28, 12, 14, 878]  19995                en
# 7            7           [16, 10751, 35]  10193                en
# 8            8           [16, 10751, 35]  20352                en
# 9            9  [16, 28, 35, 10751, 878]  38055                en
# 10          10           [16, 35, 10751]    863                en
# 11          11           [10751, 14, 12]  12155                en
# 12          12              [53, 12, 28]  27578                en
# ...

# %%
df_movies.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#I want to extract the columns title , release date and vote count
df_moviesused =df_movies[['title', 'release_date', 'vote_count']]
df_moviesused
# Out:
#                                               title release_date  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1   11/19/2010       10788
# 1                          How to Train Your Dragon    3/26/2010        7610
# 2                                        Iron Man 2     5/7/2010       12368
# 3                                         Toy Story   11/22/1995       10174
# 4                                         Inception    7/16/2010       22186
# ...                                             ...          ...         ...
# 26512                         Laboratory Conditions   10/13/2018           1
# 26513                               _EXHIBIT_84xxx_     5/1/2018           1
# 26514                                  The Last One    10/1/2018           1
# 26515                                  Trailer Made    6/22/2018           1
# 26516                                    The Church    10/5/2018           1
#
# [26517 rows x 3 columns]

# %%
df_gross.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
df_grossused = df_gross[['title', 'domestic_gross', 'foreign_gross']]
df_grossused
# Out:
#                                             title  domestic_gross
# 0                                     Toy Story 3     415000000.0  \
# 1                      Alice in Wonderland (2010)     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     296000000.0
# 3                                       Inception     292600000.0
# 4                             Shrek Forever After     238700000.0
# ...                                           ...             ...
# 3382                                    The Quake          6200.0
# 3383                  Edward II (2018 re-release)          4800.0
# 3384                                     El Pacto          2500.0
# 3385                                     The Swan          2400.0
# 3386                            An Actor Prepares          1700.0
#
#      foreign_gross
# 0        652000000
# 1        691300000
# 2        664300000
# 3        535700000
# 4        513900000
# ...            ...
# 3382           NaN
# ...

# %%
#drop the unnamed column df_movies
#merge the column name titles together
#check the info for missing values 
#check described df

# %%
# I want to extract the columns release date, budget and movie 
df_budgets.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
df_budgetsused = df_budgets[['release_date', 'movie', 'production_budget']]
df_budgetsused
# Out:
#      release_date                                        movie
# 0       18-Dec-09                                       Avatar  \
# 1       20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2        7-Jun-19                                 Dark Phoenix
# 3        1-May-15                      Avengers: Age of Ultron
# 4       15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...           ...                                          ...
# 5777    31-Dec-18                                       Red 11
# 5778     2-Apr-99                                    Following
# 5779    13-Jul-05                Return to the Land of Wonders
# 5780    29-Sep-15                         A Plague So Pleasant
# 5781     5-Aug-05                            My Date With Drew
#
#      production_budget
# 0        $425,000,000
# 1        $410,600,000
# 2        $350,000,000
# 3        $330,600,000
# 4        $317,000,000
# ...                ...
# 5777           $7,000
# ...

# %%
#I want to concatenate my 3 different dataframes
list_of_dataframes = [df_budgetsused, df_grossused, df_moviesused]
df = pd.concat(list_of_dataframes)

# %%
#I want to see what my data types are
df.dtypes
# Out:
# release_date          object
# movie                 object
# production_budget     object
# title                 object
# domestic_gross       float64
# foreign_gross         object
# vote_count           float64
# dtype: object

# %%
#from above dtypes we see that release date is a string object when it should be a date object, production budget is a string object instead of a float, foreign gross is a string object instead of a float 
df.info
# Out:
# <bound method DataFrame.info of       release_date                                        movie
# 0        18-Dec-09                                       Avatar  \
# 1        20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2         7-Jun-19                                 Dark Phoenix
# 3         1-May-15                      Avengers: Age of Ultron
# 4        15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...            ...                                          ...
# 26512   10/13/2018                                          NaN
# 26513     5/1/2018                                          NaN
# 26514    10/1/2018                                          NaN
# 26515    6/22/2018                                          NaN
# 26516    10/5/2018                                          NaN
#
#       production_budget                  title  domestic_gross foreign_gross
# 0         $425,000,000                     NaN             NaN           NaN  \
# ...
